# %%
try:
    import numpy as np
    from matplotlib import pyplot as plt
    import pandas as pd
    import pandas_datareader as pdr
    print("Every modules was loaded successfully!!!")
except:
    print("oops!! Something went wrong.")
# Out:
# Every modules was loaded successfully!!!

# %%
data = pdr.get_data_fred('FEDFUNDS')

# %%
data.describe()
# Out:
#         FEDFUNDS
# count  59.000000
# mean    1.106610
# std     0.872562
# min     0.050000
# 25%     0.090000
# 50%     1.150000
# 75%     1.870000
# max     2.420000

# %%
data.plot()
plt.show()

# %%
import pandas_datareader as pdr
data2 = pdr.get_data_fred('GS10')

# %%
data2.plot()
plt.show()

# %%
data=pdr.get_data_fred("GS20")
data.plot()
plt.show()
